# %%
import pandas as pd
import numpy as np
import pickle
import time

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score,  classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
class modelpredictor:
    
    datasetfile = file = pd.read_csv('C:\\Users\\Admin\\Desktop\\3rd sem\\book_recom_sys\\initial_dataset1.csv')    
    mf = open('C:\\Users\\Admin\\Desktop\\3rd sem\\book_recom_sys\\br1.pkl', 'rb')
    actual_data = []
    def __init__(self):
        start_time = time.time()
        print('Loading Model')
        #with open(pkl_file, 'rb') as file:  
         #   self.model = pickle.load(self.file)
        self.model = pickle.load(self.mf)
        print('Model Loaded in', time.time() - start_time)
        start_time = time.time()
        print('Processing Dataset...')
        t = self.datasetfile['Title'].to_list()
        a = self.datasetfile['Author'].to_list()
        r = self.datasetfile['Rating'].to_list()
        pr = self.datasetfile['Price'].to_list()
        w = self.datasetfile['URLs'].to_list()
        m = self.datasetfile['Main Genre'].to_list()
        s = self.datasetfile['Sub Genre'].to_list()
        for i in range(0,6778):
            l = [t[i], a[i], m[i], s[i], r[i], pr[i], w[i]]
            self.actual_data.append(l)
        print('Dataset Processed in', time.time() - start_time)
        
    def test(self, value):
        resp = self.model.predict(value)
        flag=0
        l2=[]
        for i in range(0, 6778):
            if  self.actual_data[i][2] == resp[0]:
                l2.append([self.actual_data[i][0], self.actual_data[i][1], self.actual_data[i][2], self.actual_data[i][3], self.actual_data[i][4], self.actual_data[i][5], self.actual_data[i][6]])
                flag +=1
            if flag == 10:
                break
        #print(l2)
        return l2

# %%
book = input("enter the book name: ")
gen = input("enter the genre: ")
sent = book + " " + gen
l_ts = [sent]
l2 = []
x = 1

mp = modelpredictor()
l3 = mp.test(l_ts)
sl= sorted(l3, key = lambda x: x[4], reverse = True)
for j in sl[:10]:
    print("\nSuggestion: ",x) 
    x += 1
    print('Title: ', j[0], '\nAuthor: ', j[1], '\nMain Genre: ', j[2], '\nSub Genre: ', j[3], '\nRating: ', j[4], '\nPrice: ', j[5], '\nURL: ', j[6])
# Out:
# enter the book name: holding the note
# enter the genre: music
# Loading Model
# Model Loaded in 0.2025463581085205
# Processing Dataset...
# Dataset Processed in 0.016498804092407227
#
# Suggestion:  1
# Title:  The Kite Runner
# Author:  Khaled Hosseini
# Main Genre:  Arts, Film & Photography
# Sub Genre:  Cinema & Broadcast
# Rating:  4.6
# Price:  ₹175.75
# URL:  https://www.amazon.in/Kite-Runner-Khaled-Hosseini-ebook/dp/B00B0CR0O6/ref=zg_bs_g_1318054031_d_sccl_3/000-0000000-0000000?psc=1
#
# Suggestion:  2
# Title:  Greenlights: Raucous stories and outlaw wisdom from the Academy Award-winning actor
# Author:  Matthew McConaughey
# Main Genre:  Arts, Film & Photography
# Sub Genre:  Cinema & Broadcast
# Rating:  4.6
# Price:  ₹389.00
# URL:  https://www.amazon.in/Greenlights-Raucous-stories-Academy-Award-winning/dp/1472280873/ref=zg_bs_g_1318054031_d_sccl_4/000-0000000-0000000?psc=1
#
# Suggestion:  3
# Title:  Fantastic Beasts: The Crimes of Grindelwald - The Original Screenplay
# Author:  J.K. Rowling
# Main Genre:  Arts, Film & Photography
# Sub Genre:  Cinema & Broadcast
# Rating:  4.6
# Price:  ₹313.95
# URL:  https://www.amazon.in/Fantastic-Beasts-Grindelwald-Original-Screenplay-ebook/dp/B07BL2VNNV/ref=zg_bs_g_1318054031_d_sccl_7/000-0000000-0000000?psc=1
#
# Suggestion:  4
# Title:  Black Holes (L) : The Reith Lectures [Paperback] Hawking, Stephen
# Author:  Stephen Hawking
# Main Genre:  Arts, Film & Photography
# Sub Genre:  Cinema & Broadcast
# Rating:  4.5
# Price:  ₹99.00
# URL:  https://www.amazon.in/Black-Holes-Lectures-Stephen-Hawking/dp/085750357X/ref=zg_bs_g_1318054031_d_sccl_2/000-0000000-0000000?psc=1
#
# Suggestion:  5
# Title:  The Science of Storytelling: Why Stories Make Us Human, and How to Tell Them Better
# Author:  Will Storr
# Main Genre:  Arts, Film & Photography
# Sub Genre:  Cinema & Broadcast
# Rating:  4.5
# Price:  ₹348.16
# URL:  https://www.amazon.in/Science-Storytelling-Will-Storr/dp/0008276978/ref=zg_bs_g_1318054031_d_sccl_5/000-0000000-0000000?psc=1
#
# Suggestion:  6
# Title:  Fantastic Beasts and Where to Find Them: The Original Screenplay
# Author:  J.K. Rowling
# Main Genre:  Arts, Film & Photography
# Sub Genre:  Cinema & Broadcast
# Rating:  4.5
# Price:  ₹313.95
# URL:  https://www.amazon.in/Fantastic-Beasts-Where-Find-Them-ebook/dp/B01ETJABRE/ref=zg_bs_g_1318054031_d_sccl_6/000-0000000-0000000?psc=1
#
# Suggestion:  7
# Title:  Desperately Seeking Shah Rukh : India's Lonely Young Women and the Search for Intimacy and Independence
# Author:  Shrayana Bhattacharya
# Main Genre:  Arts, Film & Photography
# Sub Genre:  Cinema & Broadcast
# Rating:  4.5
# Price:  ₹348.16
# URL:  https://www.amazon.in/Desperately-Seeking-Shah-Rukh-Independence/dp/9356292140/ref=zg_bs_g_1318054031_d_sccl_8/000-0000000-0000000?psc=1
#
# Suggestion:  8
# Title:  Save the Cat!: The Last Book on Screenwriting You'll Ever Need
# Author:  Blake Snyder
# Main Genre:  Arts, Film & Photography
# Sub Genre:  Cinema & Broadcast
# Rating:  4.5
# Price:  ₹850.00
# URL:  https://www.amazon.in/Save-Cat-Last-Screenwriting-Youll/dp/1932907009/ref=zg_bs_g_1318054031_d_sccl_9/000-0000000-0000000?psc=1
#
# Suggestion:  9
# Title:  Screenplay
# Author:  Syd Field
# Main Genre:  Arts, Film & Photography
# Sub Genre:  Cinema & Broadcast
# Rating:  4.5
# Price:  ₹644.52
# URL:  https://www.amazon.in/Screenplay-Foundations-Screenwriting-Syd-Field/dp/0385339038/ref=zg_bs_g_1318054031_d_sccl_10/000-0000000-0000000?psc=1
#
# Suggestion:  10
# Title:  The Complete Novel of Sherlock Holmes
# Author:  Arthur Conan Doyle
# Main Genre:  Arts, Film & Photography
# Sub Genre:  Cinema & Broadcast
# Rating:  4.4
# Price:  ₹169.00
# URL:  https://www.amazon.in/Complete-Novels-Sherlock-Holmes/dp/8175994312/ref=zg_bs_g_1318054031_d_sccl_1/000-0000000-0000000?psc=1
